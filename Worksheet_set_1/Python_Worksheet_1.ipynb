# %%
1.	C. %
2.	B. 0
3.	C. 24
4.	A.2
5.	D. 6
6.	B. It encloses the lines of code which will be executed if any error occurs while executing the lines of code in the try block
7.	A. Its used to raise an exception
8.	C. in defining a generator
9.	A. _abc C.abc2
10.	A. yield B. raise
11. def Factorial(n):
     
    
    return 1 if (n==1 or n==0) else n * Factorial(n - 1)

number = 17
print("Factorial value of ",number,"is",factorial(number))

12. nmb = 25
if nmb > 1:
    for i in range(2,int(nmb/2)+1):
        if (nmb % i == 0):
            print(nmb, "is not a Prime Number")
            break
    else:
        print(nmb,"is a Prime number")
else:
    print(nmb,"is not a Prime number")

13. def Palindrome_check(s):
    return word == word[::-1]
 
word = "malayalam"
ans = Palindrome_check(word)
 
if ans:
    print("Yes")
else:
    print("No")

14. def thirdside(firstside, secondside):
  
    h = (((firstside * firstside) + (secondside * secondside))**(1/2));
    return h;
  
firstside = 3;
secondside = 4;
  
print(thirdside(firstside, secondside));

15. string = "PythonFlipnWorkDataTrained"
 
freq = {}
 
for i in string:
    if i in freq:
        freq[i] += 1
    else:
        freq[i] = 1
 
print("Freq of each character in ",string," is :\n "
      + str(freq))
